# %% [markdown]
# # Import the dataset and Load the dataset. Load the necessary libraries.

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


data=pd.read_csv('uberdrive1.csv')

data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
data.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Karachi      2.9  Errand/Supplies
# 1147           Karachi      4.6  Errand/Supplies
# 1148           Karachi      4.6          Meeting
# ...

# %%
new_data=data.drop(data.index[1155])
new_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
new_data.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# ...

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
new_data.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %% [markdown]
# ## Q3. Show the dimension of the dataset. (2 points)

# %%
data.shape
# Out:
# (1156, 7)

# %%
new_data.shape
# Out:
# (1155, 7)

# %%
new_data.ndim
# Out:
# 2

# %% [markdown]
# ## Q4. Show the size of the dataset. (2 points)

# %%
data.size
# Out:
# 8092

# %%
new_data.size
# Out:
# 8085

# %% [markdown]
# ## Q5. Print the information about all the variables of the data set. (2 points)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
# START_DATE*    1155 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1155 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 72.2+ KB

# %% [markdown]
# ## Q6. Check for missing values. (2 points)

# %%
data.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
# 1155        False       True       True    True   True   False      True
#
# [1156 rows x 7 columns]

# %%
new_data.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q7. How many missing values are present? (2 points)

# %%
data.isnull().sum().sum() #check missing value
# Out:
# 507

# %%
new_data.isnull().sum().sum()
# Out:
# 502

# %% [markdown]
# ## Q8. Get the initial data (name it 'df') with dropping the NA values. (2 points)

# %%
df=data.dropna()
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Q9. Get the summary of data. (2 points)

# %%
df.describe()
# Out:
#            MILES*
# count  653.000000
# mean    11.196325
# std     22.986429
# min      0.500000
# 25%      3.200000
# 50%      6.400000
# 75%     10.400000
# max    310.300000

# %% [markdown]
# ## Q10. Check the information of the new dataframe. (2 points)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
# START_DATE*    653 non-null object
# END_DATE*      653 non-null object
# CATEGORY*      653 non-null object
# START*         653 non-null object
# STOP*          653 non-null object
# MILES*         653 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start destinations. (2 points)

# %%
df['START*'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %% [markdown]
# ## Q12. What is the total number of unique start destinations? (2 points)

# %%
df['START*'].nunique()
# Out:
# 131

# %% [markdown]
# ## Q13. Print the total number of unique stop destinations. (2 points)

# %%
df['STOP*'].unique()
df['STOP*'].nunique()
# Out:
# 137

# %% [markdown]
# ## Q14. Print all the Uber trips that has the starting point of San Fransisco. (2 points)

# %%
df[df['START*']== 'San Francisco']
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %%
data[data['START*']== 'San Francisco']
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)

# %%
df = df.dropna(subset=['START*']) 
df['START*'].value_counts().nlargest(n=1)
# Out:
# Cary    161
# Name: START*, dtype: int64

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)

# %%
df = df.dropna(subset=['STOP*']) 
df['STOP*'].value_counts().nlargest(n=1)
# Out:
# Cary    155
# Name: STOP*, dtype: int64

# %% [markdown]
# ## Q17. List the most frequent routes(same START & END points) taken by Uber drivers.
# ## (3 points)

# %%
mf=df[df[('START*')]==df[('STOP*')]]
mf.groupby(['START*','STOP*'])['PURPOSE*'].value_counts().nlargest(n=20)
# Out:
# START*            STOP*             PURPOSE*
# Cary              Cary              Errand/Supplies    14
#                                     Meal/Entertain     12
#                                     Meeting            12
# Karachi           Karachi           Errand/Supplies    10
# Unknown Location  Unknown Location  Meeting            10
#                                     Temporary Site      9
#                                     Errand/Supplies     8
# Lahore            Lahore            Meal/Entertain      6
# Cary              Cary              Customer Visit      5
# Lahore            Lahore            Errand/Supplies     5
#                                     Customer Visit      4
# Islamabad         Islamabad         Errand/Supplies     3
# Karachi           Karachi           Meeting             3
#                                     Customer Visit      2
#                                     Meal/Entertain      2
# ...

# %% [markdown]
# ## Q18. Print all types of purposes for the trip in an array. (3 points)

# %%
df['PURPOSE*'].unique()
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %% [markdown]
# ## Q19. Plot a bar graph of Purposes vs Distance. (3 points)

# %%
plt.figure(figsize=(15,10))
ax = sns.barplot(x="PURPOSE*", y="MILES*", data=df)

# %% [markdown]
# ## Q20. Print a dataframe of Purposes and the distance travelled for that particular Purpose. (3 points)

# %%
df.groupby(['PURPOSE*','START*'])['MILES*'].transform('sum')
new_df = df.drop_duplicates(subset=['PURPOSE*', 'MILES*'])
new_df.drop(new_df.columns[[0, 1, 2,3,4]], axis = 1, inplace = True) 
new_df
df2 = new_df.groupby(['PURPOSE*']).sum()
df2
# Out:
#                  MILES*
# PURPOSE*
# Airport/Travel     16.5
# Between Offices   185.2
# Charity ($)        15.1
# Commute           180.2
# Customer Visit   1960.7
# Errand/Supplies   333.7
# Meal/Entertain    583.5
# Meeting          2057.7
# Moving             18.2
# Temporary Site    468.7

# %% [markdown]
# ## Q21. Plot number of trips vs Category of trips. (3 points)

# %%
ax = sns.countplot(x="CATEGORY*", data=data)

# %% [markdown]
# ## Q22. What is proportion of trips that is Business and what is the proportion of trips that is Personal? (3 points)

# %%
r=data['CATEGORY*'].value_counts().sum()
r
s=data['CATEGORY*'].value_counts()/r*100
s
# Out:
# Business    93.333333
# Personal     6.666667
# Name: CATEGORY*, dtype: float64
